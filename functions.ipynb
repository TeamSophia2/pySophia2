# %% [markdown]
# ## pysophia2 functions

# %% [markdown]
# la mayoria de los resultados y salidas de estas funciones son listas

# %% [markdown]
# el metodo en el que se presentan las funciones son, nombre de la funcion, que hace y despues

# %% [markdown]
# se incluyó la magia `%%time` en cada ejecucion del codigo para que se haga una idea de cuanto para Wall time: 153 ms

# %% [markdown]
# todo:
# * db connection
# - tools
#     - frecuency dictionary
#     - Ngram
#     - ntlk toolkit implementation
#     - scipy
#     -
#     -

# %% [markdown]
# ### Date
# date format YYYY/MM/DD
#
# example: 2020-03-29

# %% [markdown]
# ---------

# %% [markdown]
# ## INDEX
#
#  1. DB module
#      1. [INFO](#INFO)
#          - [set_credentials(password)](#set_credentials(password="contraseña"))
#          - [list_countries()](#list_countries())
#          - [list_media_outlets()](#list_media_outlets())
#          - [stats_countries()](#stats_countries())
#          - [stats_countries_by_date(from, to)](#stats_countries_by_date())
#          - [stats_media_outlet()](#stats_media_outlet())
#          - [stats_media_outlet_by_country(country)](#stats_media_outlet_by_country(country))
#          - [stats_media_outlet_by_country_by_date(country)](#stats_media_outlet_by_country_by_date(country))
#          - [Link to the destination](#list_countries())
#
#      1. [DATASETS](#DATASETS)
#          - [dataset_by_country(country,from, to)](#dataset_by_country(country,from,to))
#  1. TOOLS #pendiente subdividir en categorias las funciones de abajo
#      * [get_frecuency(dataset)](#get_frecuency(dataset))
#      * [get_n_most_freq(freq_struct,n,graph)](#get_n_most_freq(freq_struct,n,graph))
#      * [graph_term_frecuency_bar(freq_struct,[word])](#graph_term_frecuency_bar(freq_struct,[word]))

# %% [markdown]
# -----------

# %%
??? tipos de datos como: estructura de frecuencia, datasets de noticias caleuche, fecha

# %% [markdown]
# # 1) DB module

# %% [markdown]
# ## 1.A)
# ## INFO

# %% [markdown]
# ### set_credentials(password="contraseña")
#  login into database
#
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
from sophia2 import db

# %%
# %%time
db.set_credentials(password="frmv9485")
# Out:
# Wall time: 670 ms
# 'successful connection'

# %% [markdown]
# ### list_countries()
# List countries with news listed in caleuche
#
# return a list of strings with all the countries
#
#
#
#
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
db.list_countries()
# Out:
# Wall time: 168 ms
# ['argentina',
#  'australia',
#  'brasil',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costarica',
#  'cuba',
#  'ecuador',
#  'elsalvador',
#  'espana',
#  'estadosunidos',
#  'francia',
#  'guatemala',
#  'honduras',
#  'irlanda',
#  'islascook',
#  'italia',
#  'mexico',
#  'nicaragua',
#  'nigeria',
#  'nuevazelanda',
#  'panama',
#  'papuanuevaguinea',
#  'paraguay',
#  'peru',
#  'polinesiafrancesa',
#  'portugal',
#  'puertorico',
#  'reinounido',
#  'republicadominicana',
#  'samoaamericana',
#  'uruguay',
#  'vanuatu',
#  'venezuela']

# %% [markdown]
# ### list_media_outlets()
# List countries with news listed in caleuche (prefiere un dictionario con listas o asi un dataframe?)
#
#
# return a dataframe of strings with all the countries
#
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
import pandas as pd

# %%
# %%time
db.list_media_outlets()
# Out:
# Wall time: 1min 3s
#                  country     media_outlet_name
# 0              argentina       elintransigente
# 1              argentina        lanaciononline
# 2              argentina                letrap
# 3              argentina              losandes
# 4              argentina              pagina12
# 5              argentina              tnonline
# 6              argentina               viapais
# 7              australia                 news7
# 8              australia             ninecomau
# 9              australia             sbsnewsau
# 10             australia  sidneymorningherald1
# 11             australia  sidneymorningherald2
# 12             australia  sidneymorningherald3
# 13             australia                theage
# 14             australia  theguardianaustralia
# 15                brasil              bandnews
# 16                brasil         estadodeminas
# 17                brasil          ilhanoticias
# ...

# %% [markdown]
# ### stats_countries()
# List how many news are in caleuche countries
#
# return a list of strings with all the countries
#
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
db.stats_countries()
# Out:
# Wall time: 16.9 s
#                 country  quantity
# 0             argentina     96737
# 1             australia    541364
# 2                brasil    388227
# 3                canada   1123763
# 4                 chile    955695
# 5                 china    659437
# 6              colombia    149220
# 7             costarica    181899
# 8                  cuba     91494
# 9               ecuador      8051
# 10           elsalvador    108557
# 11               espana   1091032
# 12        estadosunidos    372146
# 13              francia    678972
# 14            guatemala    128696
# 15             honduras     58633
# 16              irlanda   4509982
# 17            islascook     28441
# 18               italia    352587
# 19               mexico    269583
# 20            nicaragua    286861
# 21              nigeria    584257
# 22         nuevazelanda    581710
# 23               panama     43777
# 24     papuanuevaguinea     22416
# 25             paraguay     12357
# ...

# %% [markdown]
# ### stats_countries_by_date([from](#Date),[to](#Date))
#
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
db.stats_countries_by_date(_from='2020-03-01', _to='2020-04-01')
# Out:
# Wall time: 1min 28s
#                 country  quantity
# 0             argentina      2983
# 1             australia      4426
# 2                brasil      2048
# 3                canada      8481
# 4                 chile     14181
# 5                 china      3792
# 6              colombia      2497
# 7             costarica      3738
# 8                  cuba      1340
# 9               ecuador       111
# 10           elsalvador      1452
# 11               espana     20979
# 12        estadosunidos     10505
# 13              francia      6524
# 14            guatemala      2226
# 15             honduras      1216
# 16              irlanda      5348
# 17               italia      5581
# 18               mexico      5981
# 19            nicaragua      1772
# 20              nigeria      6687
# 21         nuevazelanda      3455
# 22               panama      1325
# 23     papuanuevaguinea       146
# 24             paraguay       408
# 25                 peru      7282
# ...

# %% [markdown]
# ### stats_media_outlet()
#
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
print(db.list_countries.__doc__)
# Out:
# provides a list with all the countries that currently have media outlets in Sun
#
#     Returns:
#         [string]: [country_name]

# %%
# %%time
db.stats_media_outlet()
# Out:
# Wall time: 31.7 s
#                  country     media_outlet_name  quantity
# 0                 espana             abcespana      9747
# 1          estadosunidos               abcnews         2
# 2                   cuba              adelante     12257
# 3                   cuba                 ahora       197
# 4                  chile     ahoranoticiasmega    169354
# 5              guatemala                 aldia      6957
# 6    republicadominicana             almomento     41893
# 7               portugal              anoticia      8414
# 8                 espana               antena3    184262
# 9              nicaragua            articulo66      7732
# 10                brasil              bandnews      7589
# 11                mexico          bbcnewsmundo     18397
# 12                 chile           biobiochile    122126
# 13              colombia           bolivarense      2034
# 14               irlanda          breakingnews      6825
# ...

# %% [markdown]
# ### stats_media_outlet_by_country(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
db.stats_media_outlet_by_country('chile')
# Out:
# Wall time: 2.41 s
#   country  media_outlet_name  quantity
# 0   chile  ahoranoticiasmega    169354
# 1   chile        biobiochile    122126
# 2   chile        elciudadano     81609
# 3   chile        elmostrador     18901
# 4   chile               emol    193606
# 5   chile            horas24    264725
# 6   chile          latercera    107155

# %% [markdown]
# ### stats_media_outlet_by_country_by_date(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
db.stats_media_outlet_by_country_by_date('chile')
# Out:
# Wall time: 2.7 s
#   country  media_outlet_name  quantity
# 0   chile  ahoranoticiasmega    169354
# 1   chile        biobiochile    122126
# 2   chile        elciudadano     81609
# 3   chile        elmostrador     18901
# 4   chile               emol    218094
# 5   chile            horas24    264725
# 6   chile          latercera    107155

# %% [markdown]
# --------------

# %% [markdown]
# ## 1.B
# ## DATASETS
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %% [markdown]
# ------

# %% [markdown]
# #### dataset_sophia2
# Las noticias descargadas desde caleuche se almacenan en una estructura de datos llamada [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) de la libreria pandas en donde cada fila corresponde a una noticia.
#
# Este dataset cuenta con las siguientes columnas para cada noticia:
#
# * id: corresponde a un id unico interno asignado por la base de datos a la noticia
# * country: pais al que pertenece el medio donde fue publicada
# * media_outlet: nombre del medio de prensa donde fue publicada
# * url: link desde donde fue extraida
# * title: titulo
# * text: cuerpo
# * date: fecha de publicacion
# * year: año de publicacion
# * journalist: autor de la noticia

# %% [markdown]
# ### dataset_by_country(<a href="#list_countries()">country</a>,[from](#Date),[to](#Date))
# retorna una estructura [dataset](#dataset)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
dataset = db.dataset_by_country('chile','2020-04-13','2020-05-13')
# Out:
# Wall time: 14 s

# %%
dataset
# Out:
#              id country media_outlet  \
# 0        107097   chile      horas24
# 1        107108   chile      horas24
# 2        107122   chile      horas24
# 3        107138   chile      horas24
# 4        107164   chile      horas24
# ...         ...     ...          ...
# 13714  13595767   chile         emol
# 13715  13595782   chile         emol
# 13716  13595814   chile         emol
# 13717  15705473   chile         emol
# 13718  15705483   chile         emol
#
#                                                      url  \
# 0      https://www.24horas.cl/nacional/socavon-en-la-...
# 1      https://www.24horas.cl/coronavirus/empresario-...
# 2      https://www.24horas.cl/coronavirus/pastor-cid-...
# 3      https://www.24horas.cl/coronavirus/alcaldesa-d...
# 4      https://www.24horas.cl/coronavirus/alcaldesa-d...
# ...                                                  ...
# 13714  https://www.emol.com/noticias/Nacional/2020/05...
# ...

# %% [markdown]
# ### dataset_by_media_outlet(<a href="#list_countries()">country</a>,[from](#Date),[to](#Date))
# retorna una estructura [dataset](#dataset)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %% [markdown]
# --------------------------------

# %% [markdown]
# # 2) TOOLS

# %%
from sophia2 import tools

# %% [markdown]
# #### frequency_struct
# Para muchas de las funciones que vienen a continuacion es necesario pasar como argumento una "frecuency_struct". Esta estructura es creada a partir de un [dataset](#dataset) cualquiera mediante la funcion [`get_frecuency()`](#get_frecuency(dataset)) y se hace con el objetivo de optimizar los tiempos de ejecucion en funciones que requieren previamente un paso en el que se obtiene un diccionario de frecuencias.
#
#
# la estructura de frecuencias es un diccionario de python que contiene los siguientes campos:
#
# * total_elements: cantidad totales de palabras en las noticias
# * dictionary: diccionario de frecuencias en donde aparece la cantidad de apariciones para cada palabra

# %% [markdown]
# ### get_frecuency([dataset_sophia2](#dataset_sophia2))
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
dataset = db.dataset_by_country('chile','2020-02-13','2020-04-13')
# Out:
# Wall time: 1min 16s

# %%
# %%time
tools.get_frecuency(dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Documents\repos\sophia2\sophia2\tools.py in get_frecuency(dataset)
#      16     """
#      17     textos=dataset["text"]
# ---> 18     concatenado = ' '.join(textos)
#      19     tokenizado = concatenado.split(" ")
#      20     qty_elements = len(tokenizado)
#
# TypeError: sequence item 0: expected str instance, tuple found

# %% [markdown]
# ### get_n_most_freq([freq_struct](#frequency_struct),n,graph)
#
# retorna una lista de n tuplas en donde cada tupla esta compuesta por la palabra y la cantidad de apariciones en los textos terminos mas frecuentes de una estructura de frecuencias, opcionalmente puedes pasar el parametro graph=true para obtener un grafico en terminos de la frecuencia para cada uno de estos n terminos
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
frequency_struct = tools.get_frecuency(dataset)
# Out:
# Wall time: 15.9 s

# %%
# %%time 
tools.get_n_most_freq(frequency_struct,5, True)
# Out:
# Wall time: 671 ms
# [('personas', 11379),
#  ('casos', 7555),
#  ('medidas', 7463),
#  ('coronavirus', 7430),
#  ('cuarentena', 5925)]

# %% [markdown]
# ### graph_term_frecuency_bar([freq_struct](#frequency_struct),[word])
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time
tools.graph_term_frecuency_bar(frequency_struct,["personas", "sebastian", "coronavirus", "covid", "piñera", "medidas"])
# Out:
# Wall time: 23 ms

# %% [markdown]
# ### 3stats_media_outlet_by_country(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
# %%time 
get_word_frequency_group_by_date

# %% [markdown]
# ### 4stats_media_outlet_by_country(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %% [markdown]
# ### 5stats_media_outlet_by_country(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %% [markdown]
# ### 6stats_media_outlet_by_country(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %% [markdown]
# ### 7stats_media_outlet_by_country(<a href="#list_countries()">country</a>)
# <div style='text-align: right'><a href="#INDEX">back to index </a></div>

# %%
def get_word_frequency_group_by_date():

# %%
dataset["date"][0].month
# Out:
# 4

# %%
dataset_groupby = dataset.groupby(dataset['date'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-568a2cd1b47c> in <module>
# ----> 1 dataset_groupby = dataset.groupby(dataset['date'].month)
#
# ~\.conda\envs\sophia\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
s

# %%
dataset.groupby(by=["date"])

# %%
def build_ngram_struct(gb_dataset):
    sophia2_ngram_struct = {}
    for key, dataset in s:
        print(type(item))
        ngram_struct[key.strftime("%Y/%m/%d")] = tools.get_frecuency(dataset)
    return ngram_struct


dataset_groupby = dataset.groupby(dataset['date'])


   
struct = build_ngram_struct(dataset_groupby)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words('italian'))
# Out:
# ['ad', 'al', 'allo', 'ai', 'agli', 'all', 'agl', 'alla', 'alle', 'con', 'col', 'coi', 'da', 'dal', 'dallo', 'dai', 'dagli', 'dall', 'dagl', 'dalla', 'dalle', 'di', 'del', 'dello', 'dei', 'degli', 'dell', 'degl', 'della', 'delle', 'in', 'nel', 'nello', 'nei', 'negli', 'nell', 'negl', 'nella', 'nelle', 'su', 'sul', 'sullo', 'sui', 'sugli', 'sull', 'sugl', 'sulla', 'sulle', 'per', 'tra', 'contro', 'io', 'tu', 'lui', 'lei', 'noi', 'voi', 'loro', 'mio', 'mia', 'miei', 'mie', 'tuo', 'tua', 'tuoi', 'tue', 'suo', 'sua', 'suoi', 'sue', 'nostro', 'nostra', 'nostri', 'nostre', 'vostro', 'vostra', 'vostri', 'vostre', 'mi', 'ti', 'ci', 'vi', 'lo', 'la', 'li', 'le', 'gli', 'ne', 'il', 'un', 'uno', 'una', 'ma', 'ed', 'se', 'perché', 'anche', 'come', 'dov', 'dove', 'che', 'chi', 'cui', 'non', 'più', 'quale', 'quanto', 'quanti', 'quanta', 'quante', 'quello', 'quelli', 'quella', 'quelle', 'questo', 'questi', 'questa', 'queste', 'si', 'tutto', 'tutti', 'a', 'c', 'e', 'i', 'l', 'o', 'ho', 'hai', 'ha', '
# ...

# %%
struct
# Out:
# {'2020/03/13/': {'total_elements': 191795,
#   'dictionary': FreqDist({'coronavirus': 320, 'personas': 306, 'medidas': 305, 'casos': 258, ',': 228, 'dos': 209, 'viernes': 190, 'parte': 189, 'caso': 185, 'nuevo': 160, ...})},
#  '2020/03/14/': {'total_elements': 99790,
#   'dictionary': FreqDist({'casos': 229, 'medidas': 219, 'personas': 205, 'coronavirus': 161, 'dos': 152, 'país': 150, 'Chile': 147, ',': 142, 'días': 114, 'clases': 112, ...})},
#  '2020/03/15/': {'total_elements': 78109,
#   'dictionary': FreqDist({'clases': 258, 'personas': 203, 'medidas': 200, 'coronavirus': 156, 'casos': 131, 'suspensión': 116, 'medida': 114, 'Universidad': 113, 'país': 113, '2020': 105, ...})},
#  '2020/03/16/': {'total_elements': 177917,
#   'dictionary': FreqDist({'personas': 430, 'medidas': 376, 'coronavirus': 312, 'país': 256, 'casos': 253, 'lunes': 237, ',': 232, 'Chile': 223, 'medida': 201, 'caso': 191, ...})},
#  '2020/03/17/': {'total_elements': 188851,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
struct
palabra= "salud"

for key in struct:
    #print(key)
    plt.scatter(key,struct[key]["dictionary"]["salud"])
    print(struct[key]["dictionary"]["salud"])
    #print(struct[key])
#x = np.arange(0,10,0.1)
#y = x*np.cos(x)

#plt.plot(x,y)
# Out:
# 137
# 105
# 61
# 181
# 155
# 234
# 195
# 190
# 104
# 109
# 257
# 185
# 153
# 160
# 158
# 62
# 66
# 164
# 168
# 188
# 206
# 149
# 80
# 97
# 178
# 242
# 147
# 130
# 72
# 54
# 49
# 128

# %%
struct
# Out:
# {'2020/03/13/': {'total_elements': 191795,
#   'dictionary': FreqDist({'coronavirus': 320, 'personas': 306, 'medidas': 305, 'casos': 258, ',': 228, 'dos': 209, 'viernes': 190, 'parte': 189, 'caso': 185, 'nuevo': 160, ...})},
#  '2020/03/14/': {'total_elements': 99790,
#   'dictionary': FreqDist({'casos': 229, 'medidas': 219, 'personas': 205, 'coronavirus': 161, 'dos': 152, 'país': 150, 'Chile': 147, ',': 142, 'días': 114, 'clases': 112, ...})},
#  '2020/03/15/': {'total_elements': 78109,
#   'dictionary': FreqDist({'clases': 258, 'personas': 203, 'medidas': 200, 'coronavirus': 156, 'casos': 131, 'suspensión': 116, 'medida': 114, 'Universidad': 113, 'país': 113, '2020': 105, ...})},
#  '2020/03/16/': {'total_elements': 177917,
#   'dictionary': FreqDist({'personas': 430, 'medidas': 376, 'coronavirus': 312, 'país': 256, 'casos': 253, 'lunes': 237, ',': 232, 'Chile': 223, 'medida': 201, 'caso': 191, ...})},
#  '2020/03/17/': {'total_elements': 188851,
# ...
